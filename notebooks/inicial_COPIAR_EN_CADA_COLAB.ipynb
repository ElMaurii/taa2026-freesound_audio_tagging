# %% [markdown]
# <a href="https://colab.research.google.com/github/ElMaurii/taa2026-freesound_audio_tagging/blob/main/notebooks/inicial_COPIAR_EN_CADA_COLAB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Configuración de Credenciales de Kaggle de forma segura
import os
from google.colab import userdata

try:
    os.environ['KAGGLE_USERNAME'] = userdata.get('KAGGLE_USERNAME')
    os.environ['KAGGLE_API_TOKEN'] = userdata.get('KAGGLE_API_TOKEN')
    print("✅ Credenciales de Kaggle configuradas correctamente desde Secrets.")
except Exception as e:
    print("❌ Asegúrate de haber configurado KAGGLE_USERNAME y KAGGLE_API_TOKEN en el panel de Secrets (ícono de llave).")

# 2. Configuración e inicialización del Repositorio de GitHub
USER = "" # <----- CAMBIAR
TOKEN = userdata.get('TOKEN') # <----- CAMBIAR
REPO = "taa2026-freesound_audio_tagging"


# Clonar solo si no se ha clonado ya en esta sesión
if not os.path.exists(REPO):
    # !git clone https://{USER}:{TOKEN}@github.com/{USER}/{REPO}.git

# ¡IMPORTANTE! Movernos adentro del repositorio para trabajar en la estructura correcta
# %cd {REPO}

# 3. Descarga de Metadatos (.csv) desde Kaggle
# Nos aseguramos de que la ruta de destino exista
os.makedirs('data/raw', exist_ok=True)

if not os.path.exists('data/raw/train_curated.csv'):
    print("Descargando metadatos de Kaggle...")
    # Descargamos los archivos específicos a la carpeta temporal adecuada
    # !kaggle competitions download -c freesound-audio-tagging-2019 -f train_curated.csv -p data/raw/
    # !kaggle competitions download -c freesound-audio-tagging-2019 -f train_noisy.csv -p data/raw/

    # Kaggle los descarga como .zip automáticamente, los descomprimimos:
    import zipfile
    for csv_file in ['train_curated.csv.zip', 'train_noisy.csv.zip']:
        path_to_zip = f"data/raw/{csv_file}"
        if os.path.exists(path_to_zip):
            with zipfile.ZipFile(path_to_zip, 'r') as zip_ref:
                zip_ref.extractall('data/raw/')
            os.remove(path_to_zip) # Limpiamos el zip para no ocupar espacio innecesario
    print("✅ CSVs descargados y listos en data/raw/")
else:
    print("✅ Los archivos CSV ya están presentes en data/raw/")

# %%
# !git config --global user.email "" # <---- CAMBIAR
# !git config --global user.name "" # <---- CAMBIAR

# Cambiar el nombre del notebook actual si querés guardarlo formalmente
#!git add .
#!git commit -m "Agrega análisis EDA y gráficos de distribución"
#!git push origin main

# %%
# SCRIPT PARA CREAR .ipynb NUEVOS

import json
import os

# Asegurar que la carpeta notebooks existe
os.makedirs('notebooks', exist_ok=True)

# Ruta de destino final
dest_path = 'notebooks/inicial_COPIAR_EN_CADA_COLAB.ipynb' # <----- CAMBIAR

# Este comando guarda el estado actual del notebook en el disco local de Colab
# (Crea un notebook básico funcional con el nombre correcto)
initial_notebook = {
 "cells": [{"cell_type": "markdown", "metadata": {}, "source": ["# 01 - Archivo inicial\n", "Inicializado desde Colab."]}],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 0
}

with open(dest_path, 'w', encoding='utf-8') as f:
    json.dump(initial_notebook, f)

print(f"¡Listo! Archivo creado localmente en: {dest_path}")
# Out:
# ¡Listo! Archivo creado localmente en: notebooks/inicial_COPIAR_EN_CADA_COLAB.ipynb

# %%
# !git add .
# !git commit -m "Agrego estructura de directorios (con info en cada uno sobre su uso) y .ipynb con celdas a copiar en cada archivo Jupyter"
# !git push origin main
# Out:
# [main 5013ac7] Agrego estructura de directorios (con info en cada uno sobre su uso) y .ipynb con celdas a copiar en cada archivo Jupyter
#  5 files changed, 5 insertions(+), 3 deletions(-)
#  delete mode 100644 notebooks/01_eda_validation.ipynb
#  delete mode 100644 notebooks/02_audio_pipeline.ipynb
#  delete mode 100644 notebooks/03_model_training.ipynb
#  create mode 100644 notebooks/inicial_COPIAR_EN_CADA_COLAB.ipynb
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 839 bytes | 839.00 KiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/ElMaurii/taa2026-freesound_audio_tagging.git
#    9bb67d2..5013ac7  main -> main
